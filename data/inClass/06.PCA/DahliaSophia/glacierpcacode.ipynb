# %%
#bringing in dependencies
import requests
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy.linalg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 #bringing in dependencies
# ----> 2 import requests
#       3 import os
#       4 import pandas as pd
#
# ModuleNotFoundError: No module named 'requests'

# %%
#bring in our glacier csv file 
ds_glacier = pd.read_csv("/Users/dahli/.vscode/MLGEO-2026/data/inClass/06.PCA/DahliaSophia/RGI2000-v7.0-G-01_alaska-attributes.csv")

#droping columns that are string data type
ds_glacier = ds_glacier.drop(columns=['rgi_id', 'glims_id', 'dem_source' ,'is_rgi6', 'glac_name', 'o2region', 'src_date'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #bring in our glacier csv file
# ----> 2 ds_glacier = pd.read_csv("/Users/dahli/.vscode/MLGEO-2026/data/inClass/06.PCA/DahliaSophia/RGI2000-v7.0-G-01_alaska-attributes.csv")
#       4 #droping columns that are string data type
#       5 ds_glacier = ds_glacier.drop(columns=['rgi_id', 'glims_id', 'dem_source' ,'is_rgi6', 'glac_name', 'o2region', 'src_date'], axis = 1)
#
# NameError: name 'pd' is not defined
